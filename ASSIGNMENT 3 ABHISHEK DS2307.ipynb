# %%
import pandas as pd
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import warnings 
warnings.filterwarnings('ignore')
import time
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
import pandas as pd
import requests
import re

# %%
driver=webdriver.Chrome()

# %% [markdown]
# # Q1

# %%
driver.get('https://www.amazon.in/')

# %%
srchs=driver.find_element(By.XPATH,'//input[@type="text"]')
srchs.click()

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search.send_keys(input('WHAT YOU WANT TODAY'))
# Out:
# WHAT YOU WANT TODAYGUITAR

# %%
CLICK_BUTTON=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div')
CLICK_BUTTON.click()

# %% [markdown]
# # Q2

# %%
driver.get('https://www.amazon.in/')

# %%
srch=driver.find_element(By.XPATH,'//input[@type="text"]')
srch.click()

# %%
item=driver.find_element(By.XPATH,'//input[@class="nav-input nav-progressive-attribute"]')
item.send_keys('watches')

# %%
srch_bar=driver.find_element(By.XPATH,'//input[@id="nav-search-submit-button"]')
srch_bar.click()

# %%
#Q2

watch_urls=[]

start = 0
end= 3

time.sleep(2)

for page in range(start,end):
    item_url=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in item_url:
        watch_urls.append(i.get_attribute('href'))
    next_btn=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[1]/div/span[1]/div[1]/div[69]/div/div/span/a[3]')

# %%
watch_urls
# Out:
# ['https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0NjIyMTQwNTg4MjY3NjEyOjE2OTM5MzIxNTc6c3BfYXRmOjIwMDYxNzM3MzQyNjk4OjowOjo&url=%2FOMAX-Analog-Lasting-Silicone-Men-SS278%2Fdp%2FB01NBU3DRV%2Fref%3Dsr_1_1_sspa%3Fkeywords%3Dwatches%26qid%3D1693932157%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
#  'https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0NjIyMTQwNTg4MjY3NjEyOjE2OTM5MzIxNTc6c3BfYXRmOjMwMDAyODA0Nzk5MzAzMjo6MDo6&url=%2FEspoir-Chronograph-Combo-Stainless-Multicolor%2Fdp%2FB08F7RR2G1%2Fref%3Dsr_1_2_sspa%3Fkeywords%3Dwatches%26qid%3D1693932157%26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
#  'https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo0NjIyMTQwNTg4MjY3NjEyOjE2OTM5MzIxNTc6c3BfYXRmOjMwMDAxNjk0Njg1MTAzMjo6MDo6&url=%2FNAVIFORCE-Military-Waterproof-Multifunctional-Wristwatch%2Fdp%2FB0B9W8WRP8%2Fref%3Dsr_1_3_sspa%3Fkeywords%3Dwatches%26qid%3D1693932157%26sr%3D8-3-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1',
# ...

# %%
len(watch_url)
# Out:
# 216

# %%
product_name = []
brand = []

returnploicy = []
delivery = []
avlable = []

for i in watch_urls:
    driver.get(i)
    time.sleep(1)
    
    
    try:
        name=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[1]/div[1]/div[2]/div[2]/div/div/div[1]/div[1]/div[2]/div[1]/div/h1/span')
        product_name.append(name.text)
    except NoSuchElementException:
        product_name.append('NO_ELEMENT')
    
    try:
        brnd=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[12]/div[2]/div[1]/table/tbody/tr[6]/td')
        brand.append(brnd.text)
    except NoSuchElementException:
        brand.append('NO_ELEMENT')
    
    try:
        prc=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[1]/div[1]/div[2]/div[2]/div/div/div[1]/div[3]/div[4]/div[1]/span[1]/span[2]/span[2]')
        price.append(prc.text)
    except NoSuchElementException:
        price.append('NO_ELEMENT')
        
    try:
        returnn=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[1]/div[1]/div[2]/div[2]/div/div/div[1]/div[14]/div[2]/div/div/div/div[2]/div/ol/li[3]/div/span/div[2]/span')
        returnploicy.append(returnn.text)
    except NoSuchElementException:
        returnploicy.append('NO_ELEMENT')
        
    try:
        dlvry=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[1]/div[1]/div[2]/div[2]/div/div/div[2]/div[3]/div/div[1]/div/div/div/form/div/div/div/div/div[3]/div/div[2]/div[9]/div[1]/div/div/div/span/span')
        delivery.append(dlvry.text)
    except NoSuchElementException:
        delivery.append('NO_ELEMENT')
        
    try:
        ablable=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[1]/div[1]/div[2]/div[2]/div/div/div[2]/div[3]/div/div[1]/div/div/div/form/div/div/div/div/div[3]/div/div[4]/div/div[1]/span')
        avlable.append(ablable.text)
    except NoSuchElementException:
        avlable.append('NO_ELEMENT')

# %%
product_name
# Out:
# ['OMAX Analog Quartz White Dial Watch with Silver Gold Tone and Long Lasting White Colour Silicone Strap for Smart Men-SS278',
#  "Espoir Analogue Chronograph Not Working Combo Pack of 3 Watches Stainless Steel Multicolor Dial for Boy's & Men's Watch - Combo Es109, Es109Black",
#  "NAVIFORCE Men's Military Digital Watches Analog Quartz Waterproof Watch Sport Multifunctional Leather Wristwatch",
#  'ALNA-TURA Ironman Avengers Led Watch with Stylish Sunglass Glowing Light with Music Watch for Birthday Return Gifts for Kids Boys',
#  'NO_ELEMENT',
#  'Casio Vintage Digital Grey Dial Unisex A-158WA-1Q ( D011 )',
#  'LOUIS DEVIN Silicone Strap Analog Wrist Watch for Men (Black/Blue/Red) | LD-BK054',
#  "TIMEX Analog Dial Men's Watch",
#  'TIMEX 3 Hands Men Analog Dial Coloured Quartz Watch, Round Dial with 30 mm Case Width',
#  'Azon Brand Digital 4 Colours Vintage Square Dial Unisex Wrist Watch for Men Watch for Women Pack of 1 (WR)',
# ...

# %%
prize = []
for i in watch_urls:
    driver.get(i)
    time.sleep(1)
    

    try:
        prc=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[1]/div[1]/div[2]/div[2]/div/div/div[1]/div[3]/div[4]/div[1]/span[2]/span[2]/span[2]')
        prize.append(prc.text)
    except NoSuchElementException:
        prize.append('NO_ELEMENT')

# %%
prize
# Out:
# ['1,487',
#  '423',
#  '2,999',
#  '399',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  '394',
#  '3,417',
#  '1,677',
#  '289',
#  '359',
#  '249',
#  '789',
#  '2,398',
#  '1,759',
#  '1,759',
#  '2,079',
#  '959',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  '33,155',
#  '318',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  '285',
#  '319',
#  '2,752',
#  '3,570',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  '265',
#  '285',
#  '7,247',
#  '339',
#  '11,995',
#  '7,497',
#  '285',
#  '265',
#  '955',
#  '269',
#  '299',
#  '849',
#  '6,247',
#  'NO_ELEMENT',
#  '329',
#  '5,097',
#  'NO_ELEMENT',
#  '639',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  '199',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  '7,497',
#  'NO_ELEMENT',
#  'NO_ELEMENT',
#  '5,997',
#  'NO_ELEMENT',
#  '239',
#  '2,699',
#  '3,417',
#  '319',
#  '789',
#  '1,487',
#  '423',
#  '2,999',
#  '399',
# ...

# %%
WATCHES=pd.DataFrame({'NAME':product_name,'BRAND':brand,'PRICE':prize,'AVLABLITY':avlable,'RETURN':returnploicy,'DELIVERY':delivery})
WATCHES
# Out:
#                                                   NAME             BRAND  \
# 0    OMAX Analog Quartz White Dial Watch with Silve...        NO_ELEMENT
# 1    Espoir Analogue Chronograph Not Working Combo ...        NO_ELEMENT
# 2    NAVIFORCE Men's Military Digital Watches Analo...        NO_ELEMENT
# 3    ALNA-TURA Ironman Avengers Led Watch with Styl...        NO_ELEMENT
# 4                                           NO_ELEMENT        NO_ELEMENT
# ..                                                 ...               ...
# 211  TIMEWEAR Men's Analog Number Dial Brown Leathe...          TIMEWEAR
# 212  NAVIFORCE Analog Men's Watch (Black Dial Brown...         NAVIFORCE
# 213                      TIMEX Analog Dial Men's Watch             TIMEX
# 214  Doublerun DD4_8017 3D Glass Date Display White...         Doublerun
# 215                 Joker & Witch Nebula Women's Watch  4.00 Centimeters
#
#           PRICE   AVLABLITY              RETURN               DELIVERY
# ...

# %%
print(len(product_name))
print(len(brand))
print(len(price))
print(len(avlable))
print(len(returnploicy))
print(len(delivery))
# Out:
# 216
# 216
# 216
# 216
# 216
# 216

# %%
WATCHES.to_csv('file.csv')

# %%
WATCHES.to_csv('D:\data classes.csv')

# %% [markdown]
# # Q3

# %%
#Q3

driver1=webdriver.Chrome()

# %%
driver1.get('https://images.google.com/')

# %%
srch2=driver1.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]')
srch2.click()

# %%
icon=driver1.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea')
icon.send_keys('fruits')

# %%
srch3=driver1.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div')
srch3.click()

# %%
for _ in range(20):
    driver1.execute_script("window.scrollBy(0,100)")
    
IMAGE=driver1.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

url_img=[]

for image in IMAGE:
    fruit=image.get_attribute('src')
    if fruit is not None:
        if(fruit[0:4] == 'http'):
            url_img.append(fruit)
for i in range(len(url_img)):
    if i > 10:
        breakBy.XPATH,
    print('DOWNLOADING STARTED {0} OF {1} images'.format(i,10))
    response=requests.get(url_img[i])
    file = open(r"D:\image dwld"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# DOWNLOADING STARTED 0 OF 10 images
# DOWNLOADING STARTED 1 OF 10 images
# DOWNLOADING STARTED 2 OF 10 images
# DOWNLOADING STARTED 3 OF 10 images
# DOWNLOADING STARTED 4 OF 10 images
# DOWNLOADING STARTED 5 OF 10 images
# DOWNLOADING STARTED 6 OF 10 images
# DOWNLOADING STARTED 7 OF 10 images
# DOWNLOADING STARTED 8 OF 10 images
# DOWNLOADING STARTED 9 OF 10 images
# DOWNLOADING STARTED 10 OF 10 images
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7768\2791399958.py in <module>
#      13 for i in range(len(url_img)):
#      14     if i > 10:
# ---> 15         breakBy.XPATH,
#      16     print('DOWNLOADING STARTED {0} OF {1} images'.format(i,10))
#      17     response=requests.get(url_img[i])
#
# NameError: name 'breakBy' is not defined

# %%
cancl=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]/input')
cancl.clear()

# %%
srch3=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]')
srch3.click()

# %%
cake_srch=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]/input')
cake_srch.send_keys('cake')

# %%
srch_click=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/button/div/span')
srch_click.click()

# %%
for _ in range(20):
    driver1.execute_script("window.scrollBy(0,100)")
    
C_IMAGE=driver1.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

url_imgs=[]

for img in C_IMAGE:
    cake=img.get_attribute('src')
    if cake is not None:
        if(cake[0:4] == 'http'):
            url_imgs.append(cake)
for i in range(len(url_imgs)):
    if i > 10:
        breakBy.XPATH,
    print('DOWNLOADING STARTED {0} OF {1} images'.format(i,10))
    response=requests.get(url_imgs[i])
    file = open(r"D:\image dwld"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# DOWNLOADING STARTED 0 OF 10 images
# DOWNLOADING STARTED 1 OF 10 images
# DOWNLOADING STARTED 2 OF 10 images
# DOWNLOADING STARTED 3 OF 10 images
# DOWNLOADING STARTED 4 OF 10 images
# DOWNLOADING STARTED 5 OF 10 images
# DOWNLOADING STARTED 6 OF 10 images
# DOWNLOADING STARTED 7 OF 10 images
# DOWNLOADING STARTED 8 OF 10 images
# DOWNLOADING STARTED 9 OF 10 images
# DOWNLOADING STARTED 10 OF 10 images
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7768\2696975278.py in <module>
#      13 for i in range(len(url_imgs)):
#      14     if i > 10:
# ---> 15         breakBy.XPATH,
#      16     print('DOWNLOADING STARTED {0} OF {1} images'.format(i,10))
#      17     response=requests.get(url_imgs[i])
#
# NameError: name 'breakBy' is not defined

# %%
cancl2=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]/input')
cancl2.clear()

# %%
srch4=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]')
srch4.click()

# %%
cars_srch=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]/input')
cars_srch.send_keys('cars')

# %%
srch_click2=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/button/div/span')
srch_click2.click()

# %%
for _ in range(20):
    driver1.execute_script("window.scrollBy(0,100)")
    
CA_IMAGE=driver1.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

url_imgss=[]

for img in CA_IMAGE:
    cars=img.get_attribute('src')
    if cars is not None:
        if(cars[0:4] == 'http'):
            url_imgss.append(cars)
for i in range(len(url_imgss)):
    if i > 10:
        BreakBy.XPATH,
    print('DOWNLOADING STARTED {0} OF {1} images'.format(i,10))
    response=requests.get(url_imgss[i])
    file = open(r"D:\image dwld"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# DOWNLOADING STARTED 0 OF 10 images
# DOWNLOADING STARTED 1 OF 10 images
# DOWNLOADING STARTED 2 OF 10 images
# DOWNLOADING STARTED 3 OF 10 images
# DOWNLOADING STARTED 4 OF 10 images
# DOWNLOADING STARTED 5 OF 10 images
# DOWNLOADING STARTED 6 OF 10 images
# DOWNLOADING STARTED 7 OF 10 images
# DOWNLOADING STARTED 8 OF 10 images
# DOWNLOADING STARTED 9 OF 10 images
# DOWNLOADING STARTED 10 OF 10 images
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7768\3570599043.py in <module>
#      13 for i in range(len(url_imgss)):
#      14     if i > 10:
# ---> 15         BreakBy.XPATH,
#      16     print('DOWNLOADING STARTED {0} OF {1} images'.format(i,10))
#      17     response=requests.get(url_imgss[i])
#
# NameError: name 'BreakBy' is not defined

# %%
cancl3=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]/input')
cancl3.clear()

# %%
srch5=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]')
srch5.click()

# %%
ml_srch=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]/input')
ml_srch.send_keys('machine learning')

# %%
srch_click3=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/button/div/span')
srch_click3.click()

# %%
for _ in range(20):
    driver1.execute_script("window.scrollBy(0,100)")
    
ML_IMAGE=driver1.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

url_ml=[]

for image in ML_IMAGE:
    mac=image.get_attribute('src')
    if mac is not None:
        if(mac[0:4] == 'http'):
            url_ml.append(mac)
            
            
for i in range(len(url_ml)):
    if i > 10:
        BreakBy.XPATH ,
    print('DOWNLOADING STARTED {0} OF {1} images'.format(i,10))
    response=requests.get(url_ml[i])
    file = open(r"D:\image dwld"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# DOWNLOADING STARTED 0 OF 10 images
# DOWNLOADING STARTED 1 OF 10 images
# DOWNLOADING STARTED 2 OF 10 images
# DOWNLOADING STARTED 3 OF 10 images
# DOWNLOADING STARTED 4 OF 10 images
# DOWNLOADING STARTED 5 OF 10 images
# DOWNLOADING STARTED 6 OF 10 images
# DOWNLOADING STARTED 7 OF 10 images
# DOWNLOADING STARTED 8 OF 10 images
# DOWNLOADING STARTED 9 OF 10 images
# DOWNLOADING STARTED 10 OF 10 images
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7768\309194252.py in <module>
#      15 for i in range(len(url_ml)):
#      16     if i > 10:
# ---> 17         BreakBy.XPATH ,
#      18     print('DOWNLOADING STARTED {0} OF {1} images'.format(i,10))
#      19     response=requests.get(url_ml[i])
#
# NameError: name 'BreakBy' is not defined

# %%
cancl4=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]/input')
cancl4.clear()

# %%
srch6=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]')
srch6.click()

# %%
gt_srch=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/div/div[2]/input')
gt_srch.send_keys('guitar')

# %%
srch_click4=driver1.find_element(By.XPATH,'/html/body/c-wiz/c-wiz/div/div[3]/div[2]/div/div[1]/form/div[1]/div[2]/button/div/span')
srch_click4.click()

# %%
for _ in range(20):
    driver1.execute_script("window.scrollBy(0,100)")
    
gt_IMAGE=driver1.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

url_gt=[]

for image in gt_IMAGE:
    guitar=image.get_attribute('src')
    if guitar is not None:
        if(guitar[0:4] == 'http'):
            url_gt.append(guitar)
            
            
for i in range(len(url_gt)):
    if i > 10:
        Breakby.XPATH,
    print('DOWNLOADING STARTED {0} OF {1} images'.format(i,10))
    response=requests.get(url_gt[i])
    file = open(r"D:\image dwld"+str(i)+".jpg","wb")
    file.write(response.content)
# Out:
# DOWNLOADING STARTED 0 OF 10 images
# DOWNLOADING STARTED 1 OF 10 images
# DOWNLOADING STARTED 2 OF 10 images
# DOWNLOADING STARTED 3 OF 10 images
# DOWNLOADING STARTED 4 OF 10 images
# DOWNLOADING STARTED 5 OF 10 images
# DOWNLOADING STARTED 6 OF 10 images
# DOWNLOADING STARTED 7 OF 10 images
# DOWNLOADING STARTED 8 OF 10 images
# DOWNLOADING STARTED 9 OF 10 images
# DOWNLOADING STARTED 10 OF 10 images
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7768\1241182494.py in <module>
#      15 for i in range(len(url_gt)):
#      16     if i > 10:
# ---> 17         Breakby.XPATH,
#      18     print('DOWNLOADING STARTED {0} OF {1} images'.format(i,10))
#      19     response=requests.get(url_gt[i])
#
# NameError: name 'Breakby' is not defined

# %% [markdown]
# # Q4

# %%
#Q4

driver.get('https://www.flipkart.com/')

# %%
phone=driver.find_element(By.CLASS_NAME,"_3OO5Xc")
phone.click()

# %%
SRCHH=driver.find_element(By.CLASS_NAME,"_3704LK")
SRCHH.send_keys('samsung mobiles')

# %%
clickk=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
clickk.click()

# %%
Brand_Namee1=[] 
phone_namee1=[]
Colourr1=[]
RAMM1=[] 
ROMM1=[] 
Primary_Cameraa1=[]
Secondary_Cameraa1=[]
Displayy2 = [] 
Batteryy1=[]
Pricee1=[] 
url_link=[]

# %%
links=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for i in links:
    url_link.append(i.get_attribute('href'))
    
time.sleep(1)

# %%
url_link
# Out:
# ['https://www.flipkart.com/samsung-galaxy-f13-nightsky-green-64-gb/p/itmeadfda1bd23fa?pid=MOBGENJWF4KJTPEN&lid=LSTMOBGENJWF4KJTPENS2XJXA&marketplace=FLIPKART&store=tyy%2F4io&spotlightTagId=BestsellerId_tyy%2F4io&srno=b_1_1&otracker=product_breadCrumbs_SAMSUNG%20Mobiles&fm=organic&iid=aef43cc2-d08c-45e2-9afc-14f585749833.MOBGENJWF4KJTPEN.SEARCH&ppt=browse&ppn=browse&ssid=0srbf01y0w0000001694006384962',
#  'https://www.flipkart.com/samsung-galaxy-f13-sunrise-copper-64-gb/p/itm0d8c65ec17621?pid=MOBGENJWWRYSFC5P&lid=LSTMOBGENJWWRYSFC5P0ONQMC&marketplace=FLIPKART&store=tyy%2F4io&srno=b_1_2&otracker=product_breadCrumbs_SAMSUNG%20Mobiles&fm=organic&iid=aef43cc2-d08c-45e2-9afc-14f585749833.MOBGENJWWRYSFC5P.SEARCH&ppt=pp&ppn=pp&ssid=0srbf01y0w0000001694006384962',
# ...

# %%
print(len(url_link))
# Out:
# 24

# %%
for i in url_link:
    driver.get(i)
    time.sleep(1)

    try:
        read_more=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/button')
        read_more.click()
    except:
        NoSuchElementException
        
    try:
        mname=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div/div[1]/table/tbody/tr[3]/td[2]/ul/li')
        phone_namee1.append(mname.text)
    except NoSuchElementException:
        phone_namee1.append('NO_ELEMENT')
    
    try:
        prz=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div[4]/div[1]/div/div[1]')
        Pricee1.append(prz.text)
    except NoSuchElementException:
        Pricee1.append('NO_ELEMENT')
    
    try:
        brnd=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div[1]/h1/span')
        Brand_Namee1.append(brnd.text)
    except NoSuchElementException:
        Brand_Namee1.append('NO_ELEMENT')
        
    try:
        color=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div[1]/div[1]/table/tbody/tr[4]/td[2]/ul/li')
        Colourr1.append(color.text)
    except NoSuchElementException:
        Colourr1.append('NO_ELEMENT')
        
    try:
        ram=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div[1]/div[4]/table/tbody/tr[2]/td[2]/ul/li')
        RAMM1.append(ram.text)
    except NoSuchElementException:
        RAMM1.append('NO_ELEMENT')
        
    try:
        rom=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div[1]/div[4]/table/tbody/tr[1]/td[2]/ul/li')
        ROMM1.append(rom.text)
    except NoSuchElementException:
        ROMM1.append('NO_ELEMENT')
        
    try:
        PCamera=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div[1]/div[5]/table/tbody/tr[2]/td[2]/ul/li')
        Primary_Cameraa1.append(PCamera.text)
    except NoSuchElementException:
        Primary_Cameraa1.append('NO_ELEMENT')
    
    try:
        SCamera=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div[1]/div[5]/table/tbody/tr[6]/td[2]/ul/li')
        Secondary_Cameraa1.append(SCamera.text)
    except NoSuchElementException:
        Secondary_Cameraa1.append('NO_ELEMENT')
    
    try:
        dplay=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[7]/div[4]/div/div[2]/div[1]/div[2]/table/tbody/tr[1]/td[2]/ul/li')
        Displayy2.append(dplay.text)
    except NoSuchElementException:
        Displayy2.append('NO_ELEMENT')
    
    try:
        btry=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/div[1]/div[10]/table/tbody/tr[1]/td[2]/ul/li')
        Batteryy1.append(btry.text)
    except NoSuchElementException:
        Batteryy1.append('NO_ELEMENT')

# %%
print(len(Brand_Namee1))
print(len(phone_namee1))
print(len(Colourr1))
print(len(RAMM1))
print(len(ROMM1))
print(len(Primary_Cameraa1))
print(len(Secondary_Cameraa1))
print(len(Displayy2))
print(len(Batteryy1))
print(len(Pricee1)) 
print(len(url_link))
# Out:
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24
# 24

# %%
df=pd.DataFrame({'BRAND':Brand_Namee1,'MOBILE':phone_namee1,'COLOUR':Colourr1,'RAM':RAMM1,'ROM':ROMM1,'PRIMARY_CAMERA':Primary_Cameraa1,'SECONDARY_CAMERA':Secondary_Cameraa1,'DISPLAY_SIZE':Displayy2,'PRICE':Pricee1,'BATTERY':Batteryy1,'PRODUCT_URL':url_link})
df
# Out:
#                                                 BRAND         MOBILE  \
# 0   SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)  (4...     Galaxy F13
# 1   SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)  (4...     Galaxy F13
# 2   SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)  (4...     NO_ELEMENT
# 3   SAMSUNG Galaxy F13 (Sunrise Copper, 128 GB)  (...     Galaxy F13
# 4   SAMSUNG Galaxy M04 (Dark Blue, 64 GB)  (4 GB RAM)     NO_ELEMENT
# 5   SAMSUNG Galaxy M14 5G (Smoky Teal, 128 GB)  (6...     NO_ELEMENT
# 6   SAMSUNG Galaxy F04 (Jade Purple, 64 GB)  (4 GB...     Galaxy F04
# 7   SAMSUNG Galaxy F13 (Nightsky Green, 128 GB)  (...     Galaxy F13
# 8                        SAMSUNG Guru Music 2  (Gold)     NO_ELEMENT
# 9   SAMSUNG Galaxy F04 (Opal Green, 64 GB)  (4 GB ...     Galaxy F04
# 10  SAMSUNG Galaxy F13 (Waterfall Blue, 128 GB)  (...     Galaxy F13
# 11  SAMSUNG Galaxy F34 5G (Electric Black, 128 GB)...  Galaxy F34 5G
# 12  SAMSUNG Galaxy F23 5G (Forest Green, 128 GB)  ...  Galaxy F23 5G
# ...

# %%
df.to_csv('files2.csv')

# %% [markdown]
# # Q5

# %%
#Q5

driver.get('https://www.google.com/maps')

# %%
map=driver.find_element(By.XPATH,'/html/body/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/form')
map.click()

# %%
map_srch=driver.find_element(By.XPATH,'/html/body/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/form/input')
map_srch.send_keys('GOHANA')

# %%
map_btn=driver.find_element(By.XPATH,'/html/body/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/div[1]/button')
map_btn.click()

# %%
try:
    url_string=driver.current_url
    print('Fetch url ',url_string)
    lat_long=re.findall(r'@(.*)data',url_string)
except:
    NoSuchElementException
# Out:
# Fetch url  https://www.google.com/maps/place/Gohana,+Haryana+131301/@29.1390443,76.6548108,13z/data=!3m1!4b1!4m6!3m5!1s0x390decd90e07f1d5:0xe86589ac490395a2!8m2!3d29.1393132!4d76.6944877!16zL20vMGY0eGZq?entry=ttu

# %%
lat_long
# Out:
# ['29.1390443,76.6548108,13z/']

# %%
coordinates =lat_long[0].split(',')
print(coordinates[0:2])
# Out:
# ['29.1390443', '76.6548108']

# %% [markdown]
# # Q6

# %%
#Q6

driver.get('https://www.digit.in/')

# %%
lap=driver.find_element(By.XPATH,'/html/body/div[2]/div/ul/li[2]/span')
lap.click()

# %%
lap1=driver.find_element(By.XPATH,'/html/body/div[2]/div/ul/li[2]/div[2]/div/div[1]/span[4]')
lap1.click()

# %%
best=driver.find_element(By.XPATH,'/html/body/div[2]/div/ul/li[2]/div[2]/div/div[5]/div/div[2]/a/div')
best.click()

# %%
lap_link=[]

Links=driver.find_elements(By.XPATH,'//div[@class="lowest_price"]/a')
for i in Links:
    lap_link.append(i.get_attribute('href'))

# %%
lap_link
# Out:
# ['https://www.digit.in/flipkart/intermediate?url=https://www.flipkart.com/msi-gt77-titan-core-i9-12th-gen-64-gb-2-tb-ssd-windows-11-home-16-gb-graphics-nvidia-geforce-rtx-3080ti-120-hz-12uhs-054in-gaming-laptop/p/itm991484fe8dca9?pid=COMGH9GXEBVM7NFW&affid=OR9Dot9&affExtParam1=amp_mapped_table&affExtParam2=top_10',
#  'https://www.digit.in/amazon/intermediate?url=https://www.amazon.in/dp/B0BDZYP2H2?tag=laptoptop10plamp-21',
#  'https://www.digit.in/amazon/intermediate?url=https://www.amazon.in/dp/B0BW39FLLG?tag=laptoptop10plamp-21',
#  'https://www.digit.in/amazon/intermediate?url=https://www.amazon.in/dp/B0BYN7CS3Y?tag=laptoptop10plamp-21',
#  'https://www.digit.in/amazon/intermediate?url=https://www.amazon.in/dp/B0B93VJXYS?tag=laptoptop10plamp-21',
#  'https://www.digit.in/amazon/intermediate?url=https://www.amazon.in/dp/B0C3XSMYL1?tag=laptoptop10plamp-21']

# %%
flipkart=lap_link[0]
flipkart
# Out:
# 'https://www.digit.in/flipkart/intermediate?url=https://www.flipkart.com/msi-gt77-titan-core-i9-12th-gen-64-gb-2-tb-ssd-windows-11-home-16-gb-graphics-nvidia-geforce-rtx-3080ti-120-hz-12uhs-054in-gaming-laptop/p/itm991484fe8dca9?pid=COMGH9GXEBVM7NFW&affid=OR9Dot9&affExtParam1=amp_mapped_table&affExtParam2=top_10'

# %%
amazon=lap_link[1:]
amazon
# Out:
# ['https://www.digit.in/amazon/intermediate?url=https://www.amazon.in/dp/B0BDZYP2H2?tag=laptoptop10plamp-21',
#  'https://www.digit.in/amazon/intermediate?url=https://www.amazon.in/dp/B0BW39FLLG?tag=laptoptop10plamp-21',
#  'https://www.digit.in/amazon/intermediate?url=https://www.amazon.in/dp/B0BYN7CS3Y?tag=laptoptop10plamp-21',
#  'https://www.digit.in/amazon/intermediate?url=https://www.amazon.in/dp/B0B93VJXYS?tag=laptoptop10plamp-21',
#  'https://www.digit.in/amazon/intermediate?url=https://www.amazon.in/dp/B0C3XSMYL1?tag=laptoptop10plamp-21']

# %%
bb_name=[]
bl_name=[]
bprice_l= []
bcolor_l= []
bram_l = []
bcore_l= []
bavlb= []
bscrren=[]
boper_s = []

bgraph=[]
bg_proc = []
bdelvry = []

# %%
for i in amazon:
    driver.get(i)
    time.sleep(1)
   
    try:
        name=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[45]/div/div[1]/div/table/tbody/tr[2]/td[2]/span')
        bl_name.append(name.text)
    except NoSuchElementException:
        bl_name.append('NO_ELEMENT')
    
    try:
        Lprz=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[12]/div[4]/div[1]/span[2]/span[2]/span[2]')
        bprice_l.append(Lprz.text)
    except NoSuchElementException:
        bprice_l.append('NO_ELEMENT')
    
    try:
        brndd=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[45]/div/div[1]/div/table/tbody/tr[1]/td[2]/span')
        bb_name.append(brndd.text)
    except NoSuchElementException:
        bb_name.append('NO_ELEMENT')
        
    try:
        lcolor=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[45]/div/div[1]/div/table/tbody/tr[4]/td[2]/span')
        bcolor_l.append(lcolor.text)
    except NoSuchElementException:
        bcolor_l.append('NO_ELEMENT')
        
    try:
        Lram=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[45]/div/div[1]/div/table/tbody/tr[6]/td[2]/span')
        bram_l.append(Lram.text)
    except NoSuchElementException:
        bram_l.append('NO_ELEMENT')
        
    try:
        see_more=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[45]/div/div[2]/a/span')
        see_more.click()
    except:
        NoSuchElementException
          
    try:
        core=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[45]/div/div[1]/div/table/tbody/tr[5]/td[2]/span')
        bcore_l.append(core.text)
    except NoSuchElementException:
        bcore_l.append('NO_ELEMENT')
    
    try:
        screen=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[45]/div/div[1]/div/table/tbody/tr[3]/td[2]/span')
        bscrren.append(screen.text)
    except NoSuchElementException:
        bscrren.append('NO_ELEMENT')
    
   
    
    try:
        alb=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[3]/div[1]/div[3]/div/div[1]/div/div[1]/div/div/div[2]/div/div[2]/div/form/div/div/div[4]/div/div[1]/span')
        bavlb.append(alb.text)
    except NoSuchElementException:
        bavlb.append('NO_ELEMENT')
        
    try:
        delivery=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[3]/div[1]/div[3]/div/div[1]/div/div[1]/div/div/div[2]/div/div[2]/div/form/div/div/div[2]/div[9]/div[1]/div/div/div/span/span')
        bdelvry.append(delivery.text)
    except NoSuchElementException:
        bdelvry.append('NO_ELEMENT') 
   
    
    try:
        oss=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[45]/div/div[1]/div/table/tbody/tr[7]/td[2]/span')
        boper_s.append(oss.text)
    except NoSuchElementException:
        boper_s.append('NO_ELEMENT')
        
    try:
        gcardd=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[45]/div/div[1]/div/table/tbody/tr[9]/td[2]/span')
        bgraph.append(gcardd.text)
    except NoSuchElementException:
        bgraph.append('NO_ELEMENT')
        
    try:
        grap_procc=driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[5]/div[3]/div[4]/div[45]/div/div[1]/div/table/tbody/tr[10]/td[2]/span')
        bg_proc.append(grap_procc.text)
    except NoSuchElementException:
        bg_proc.append('NO_ELEMENT')

# %%
driver.get(flipkart)
time.sleep(1)
try:
    read_more=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[5]/div/div[2]/button')
    read_more.click()
except:
    NoSuchElementException
   
try:
    llname=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[6]/div/div/div[3]/div/div[2]/div/div[1]/table/tbody/tr[4]/td[2]/ul/li')
    bl_name.append(llname.text)
except NoSuchElementException:
    bl_name.append('NO_ELEMENT')
    
try:
    Llaprz=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[1]/div/div[2]/div/div/div/span')
    bprice_l.append(Llaprz.text)
except NoSuchElementException:
    bprice_l.append('NO_ELEMENT')
    
try:
    brandd=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[1]/div/div[1]/h1/span')
    bb_name.append(brandd.text)
except NoSuchElementException:
    bb_name.append('NO_ELEMENT')
        
try:
    llcolor=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[6]/div/div/div[3]/div/div[2]/div/div[1]/table/tbody/tr[6]/td[2]/ul/li')
    bcolor_l.append(llcolor.text)
except NoSuchElementException:
    bcolor_l.append('NO_ELEMENT')
        
try:
    lLram=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[6]/div/div/div[3]/div/div[2]/div/div[2]/table/tbody/tr[8]/td[2]/ul/li')
    bram_l.append(lLram.text)
except NoSuchElementException:
    bram_l.append('NO_ELEMENT')
        
        
try:
    ccore=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[6]/div/div/div[3]/div/div[2]/div/div[2]/table/tbody/tr[4]/td[2]/ul/li')
    bcore_l.append(ccore.text)
except NoSuchElementException:
    bcore_l.append('NO_ELEMENT')
    
try:
    sscreen=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[6]/div/div/div[3]/div/div[2]/div/div[5]/table/tbody/tr[2]/td[2]/ul/li')
    bscrren.append(sscreen.text)
except NoSuchElementException:
    bscrren.append('NO_ELEMENT')
    
try:
    oos=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[6]/div/div/div[3]/div/div[2]/div/div[3]/table/tbody/tr[2]/td[2]/ul/li')
    boper_s.append(oos.text)
except NoSuchElementException:
    boper_s.append('NO_ELEMENT')
        
try:
    ggcard=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[6]/div/div/div[3]/div/div[2]/div/div[2]/table/tbody/tr[2]/td[2]/ul/li')
    bgraph.append(ggcard.text)
except NoSuchElementException:
    bgraph.append('NO_ELEMENT')
        
try:
    gGrap_proc=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[6]/div/div/div[3]/div/div[2]/div/div[2]/table/tbody/tr[17]/td[2]/ul/li')
    bg_proc.append(gGrap_proc.text)
except NoSuchElementException:
    bg_proc.append('NO_ELEMENT')
    
try:
    aalb=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[2]/div')
    bavlb.append(aalb.text)
except NoSuchElementException:
    bavlb.append('NO_ELEMENT')
        
try:
    ddelivery=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[2]/div')
    bdelvry.append(ddelivery.text)
except NoSuchElementException:
    bdelvry.append('NO_ELEMENT')

# %%
print(bb_name)
print(bl_name)
print(bprice_l)
print(bcore_l)
print(bcolor_l)
print(bram_l)
print(bavlb)
print(bscrren)
print(boper_s)
print(bgraph)
print(bg_proc)
print(bdelvry)
# Out:
# ['Lenovo', 'NO_ELEMENT', 'Acer', 'NO_ELEMENT', 'Multimedia, Student, Gaming', 'MSI GT77 Titan Core i9 12th Gen Intel® Core™ i9-12900HX-16 Cores - (64 GB/2 TB SSD/Windows 11 Home/16 GB Graphics/NVIDIA GeForce RTX 3080Ti/120 Hz/175 W) GT77 12UHS-054IN Gaming Laptop  (17.3 inch, Black, 3.3 kg)']
# ['Legion 5 Pro 16IAH7H', 'NO_ELEMENT', 'Predator Helios Neo 16', 'NO_ELEMENT', 'MSI', 'GT77 12UHS-054IN']
# ['2,19,990', 'NO_ELEMENT', '1,44,990', 'NO_ELEMENT', '1,24,990', 'Price: Not Available']
# ['Core i7', '1 TB', 'Core i7', 'NO_ELEMENT', '16 GB', '']
# ['Storm Grey', 'NO_ELEMENT', 'grey', 'NO_ELEMENT', '15.6 Inches', 'Black']
# ['32 GB', 'Core i9', '16 GB', 'NO_ELEMENT', '', '']
# ['In stock', 'Only 1 left in stock', 'In stock', 'NO_ELEMENT', 'Only 1 left in stock', 'Currently Unavailable']
# ['16 Inches', '45.72 Centimetres', '16 Inches', 'NO_ELEMENT', 'Windows 11 Home', '']
# ['Windows 11 Home', '32 GB', 'Windows 11 Home', 'NO_ELEMENT', 'Laptop, Adapter, MSI Bag', '']
# ...

# %%
rem=driver.find_element(By.XPATH,'/html/body/div[9]/div[1]/div[3]/div[2]/div[1]/div[1]/div/span[2]')
rem.click()

# %%
laptop_name=driver.find_element(By.XPATH,'//h2[@class="heading"]')
bl_name.append(laptop_name.text)

# %%
laptop_prz=driver.find_element(By.XPATH,'//div[@class="price"]/h2')
bprice_l.append(laptop_prz.text)

# %%
Digit = []
try:
    digit=driver.find_element(By.XPATH,'/html/body/div[7]/div[2]/div[9]/div')
    Digit.append(digit.text)
except NoSuchElementException:
    Digit.append('NO_ELEMENT')

# %%
Digit
# Out:
# ['Basic Information\nModel name : Omen 17\nLaunch date (global) : 12-05-2023\noperating system (with version) : Windows 11 Home\nDisplay\nResolution : 2560 x 1440\ndisplay size (in inches) : 17.3\nRefresh Rate : 165 HzHz\nConnectivity\nconnectivity : Bluetooth, Wi-Fi\nMemory\nram included (in gb) : 16 GB\nram type : DDR5\nram speed (in mhz) : 4800\nPhysical Specifications\nlaptop weight (in kgs) : 2.78\nlaptop dimension (in mm) : 397.1 x 262 x 27\nProcessor\nprocessor model name : 13th Gen Intel Core i7-13700HX\nclock speed : 5.0 GHz\ncores : 16\ngraphics processor : NVIDIA GeForce RTX 4080\nGPU Memory type : DDR6\nGPU Memory amount : 12 GB\nCache L3 : 30 MB\nBoost Clock Speed : 5.0 GHz\nStorage\nStorage drive type : SSD\nStorage drive capacity : 1 TB\nPower\nbattery type : 6 Cell, 83 WHr\npower supply : 330 W\nSound\nWarranty And Manufacturer Info\nDetails Of Pre-Installed Software']

# %%
bcolor_l.append('not defined')

# %%
for entry in Digit:
    
    values = entry.split('\n')
    
    
    bb_name.append(values[1])
 
   
    
    bram_l.append(values[12])
    bcore_l.append(values[19])
    bscrren.append(values[6])
    bavlb.append('yes')
    boper_s.append(values[3])
    bgraph.append('yes')
    bg_proc.append(values[21])
    bdelvry.append('no_value')

# %%
print(len(bb_name))
print(len(bl_name))
print(len(bprice_l))
print(len(bcore_l))
print(len(bcolor_l))
print(len(bram_l))
print(len(bavlb))
print(len(bscrren))
print(len(boper_s))
print(len(bgraph))
print(len(bg_proc))
print(len(bdelvry))
# Out:
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7

# %%
df6=pd.DataFrame({'BRAND':bb_name,'LAPTOP_NAME':bl_name,'PRICE':bprice_l,'COLOR':bcolor_l,'RAM':bram_l,'CORE':bcore_l,'DISPLAY_SIZE':bscrren,'OS':boper_s,'GRAPHICS_CARD':bgraph,'GRAPHIC_CARD_PROCESSOR':bg_proc,'AVAILABLE':bavlb,'DELIVERY':bdelvry})
df6
# Out:
#                                                BRAND  \
# 0                                             Lenovo
# 1                                         NO_ELEMENT
# 2                                               Acer
# 3                                         NO_ELEMENT
# 4                        Multimedia, Student, Gaming
# 5  MSI GT77 Titan Core i9 12th Gen Intel® Core™ i...
# 6                               Model name : Omen 17
#
#                                          LAPTOP_NAME  \
# 0                               Legion 5 Pro 16IAH7H
# 1                                         NO_ELEMENT
# 2                             Predator Helios Neo 16
# 3                                         NO_ELEMENT
# 4                                                MSI
# 5                                   GT77 12UHS-054IN
# 6  HP Omen 17-ck2008TX 13th Gen Core i7-13700HX V...
#
#                                                PRICE        COLOR  \
# ...

# %%
#Q7

driver.get('https://www.forbes.com/')

# %%
forbs=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[1]/div[1]/div')
forbs.click()

# %%
bln=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[1]/div[1]/div/div[2]/ul/li[2]')
bln.click()

# %%
top=driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div/section/div[2]/div/div/div[1]/div/div[1]/div/a/div')
top.click()

# %%
billonairz = []

start = 0
end = 14

for page in range(start, end):
    c = driver.find_elements(By.XPATH, '//div[@class="TableRow_row__L-0Km"]')
    for i in c:
        billonairz.append(i.text)
    
    clk = driver.find_element(By.XPATH, '/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[2]/div[2]/div[1]/button[2]')
    clk.click()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8076\323670677.py in <module>
#      11     # After scraping the data from the current page, click the next page button
#      12     clk = driver.find_element(By.XPATH, '/html/body/div[1]/div[2]/div[3]/div[2]/div[2]/div[2]/div[2]/div[2]/div[1]/button[2]')
# ---> 13     clk.click()
#      14
#      15 # Now, the billonair list should contain data from all the pages
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      92     def click(self) -> None:
#      93         """Clicks the element."""
# ---> 94         self._execute(Command.CLICK_ELEMENT)
#      95
#      96     def submit(self):
#
# ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
# ...

# %%
len(billonairz)
# Out:
# 2627

# %%
billonairz[2626]
# Out:
# '1\nBernard Arnault & family\n$211 B\n74\nFrance\nLVMH\nFashion & Retail'

# %%
billon = []

first_name=driver.find_element(By.XPATH,'//div[@class="TableRow_row__L-0Km TableRow_activeRow__g4oSF"]')
billon.append(first_name.text)

# %%
billon
# Out:
# ['1\nBernard Arnault & family\n$211 B\n74\nFrance\nLVMH\nFashion & Retail']

# %%
abc=billon+billonairz
abc
# Out:
# ['1\nBernard Arnault & family\n$211 B\n74\nFrance\nLVMH\nFashion & Retail',
#  '2\nElon Musk\n$180 B\n51\nUnited States\nTesla, SpaceX\nAutomotive',
#  '3\nJeff Bezos\n$114 B\n59\nUnited States\nAmazon\nTechnology',
#  '4\nLarry Ellison\n$107 B\n78\nUnited States\nOracle\nTechnology',
#  '5\nWarren Buffett\n$106 B\n92\nUnited States\nBerkshire Hathaway\nFinance & Investments',
#  '6\nBill Gates\n$104 B\n67\nUnited States\nMicrosoft\nTechnology',
#  '7\nMichael Bloomberg\n$94.5 B\n81\nUnited States\nBloomberg LP\nMedia & Entertainment',
#  '8\nCarlos Slim Helu & family\n$93 B\n83\nMexico\nTelecom\nTelecom',
#  '9\nMukesh Ambani\n$83.4 B\n65\nIndia\nDiversified\nDiversified',
#  '10\nSteve Ballmer\n$80.7 B\n67\nUnited States\nMicrosoft\nTechnology',
#  "11\nFrancoise Bettencourt Meyers & family\n$80.5 B\n69\nFrance\nL'Oréal\nFashion & Retail",
#  '12\nLarry Page\n$79.2 B\n50\nUnited States\nGoogle\nTechnology',
#  '13\nAmancio Ortega\n$77.3 B\n87\nSpain\nZara\nFashion & Retail',
# ...

# %%
Rank = [] 
Name_bln = [] 
Net_worth = []
Age = []
Citizenship = [] 
Source = [] 
Industry = []

for entry in abc:
    
    values = entry.split('\n')
    
    
    Rank.append(values[0])
    Name_bln.append(values[1])
    Net_worth.append(values[2])
    Age.append(values[3])
    Citizenship.append(values[4])
    Source.append(values[5])
    Industry.append(values[6])

# %%
df7=pd.DataFrame({'RANK':Rank,'NAME':Name_bln,'NET WORTH':Net_worth,'AGE':Age,'CITIZINSHIP':Citizenship,'SOURCE':Source,'INDUSTRY':Industry})
df7
# Out:
#       RANK                      NAME NET WORTH AGE    CITIZINSHIP  \
# 0        1  Bernard Arnault & family    $211 B  74         France
# 1        2                 Elon Musk    $180 B  51  United States
# 2        3                Jeff Bezos    $114 B  59  United States
# 3        4             Larry Ellison    $107 B  78  United States
# 4        5            Warren Buffett    $106 B  92  United States
# ...    ...                       ...       ...  ..            ...
# 2623  2540    Richard Yuengling, Jr.      $1 B  80  United States
# 2624  2540             Zhang Gongyun      $1 B  60          China
# 2625  2540    Zhang Guiping & family      $1 B  71          China
# 2626  2540               Inigo Zobel      $1 B  66    Philippines
# 2627     1  Bernard Arnault & family    $211 B  74         France
#
#                             SOURCE               INDUSTRY
# 0                             LVMH       Fashion & Retail
# ...

# %%
#Q8
driver.get('https://www.youtube.com/')

# %%
video=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-browse/ytd-two-column-browse-results-renderer/div[1]/ytd-rich-grid-renderer/div[7]/ytd-rich-grid-row[1]/div/ytd-rich-item-renderer[2]/div/ytd-rich-grid-media/div[1]/div[1]')
video.click()

# %%
COMMENTs = []
TIMEE = []
LIKEE = []


for _ in range(40):
    driver.execute_script("window.scrollBy(0,500)")
    comments=driver.find_elements(By.XPATH,'//*[@id="content-text"]')
    for i in comments:
        COMMENTs.append(i.text)
        
    time=driver.find_elements(By.XPATH,'//*[@id="header-author"]')
    for i in time:
        TIMEE.append(i.text)
    
    like=driver.find_elements(By.XPATH,'//*[@id="vote-count-middle"]')
    for i in like:
        LIKEE.append(i.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8076\824612983.py in <module>
#      20 for i in range(len(COMMENTs)):
#      21     if i > 500:
# ---> 22         Breakby.XPATH
#      23 for i in range(len(TIMEE)):
#      24     if i > 500:
#
# NameError: name 'Breakby' is not defined

# %%
COMMENTs
# Out:
# ['ನವ ಭಾರತದ ನಿರ್ಮಾತ್ರು ವಿಶ್ವನಾಯಕ ಭಾರತಾಂಭೆಯ ಹೆಮ್ಮೆಯ ಪುತ್ರ ನರೇಂದ್ರ ಮೋದಿಜಿ ️ಜೈ ಭಾರತ ಜೈ ಮೋದಿ',
#  'Really I have no language to express the  great attitude, manner, mindset, intelligence, talking style, thinking about normal people etc. of all about our  honorable P.M Narendra Damodar Das Modi . Only I want to say that really he is a real hero in India . Jai Hind ️🇮🇳️',
#  'नरेंद्र मोदी सिर्फ नाम नही देश की शान है नमन है उनके हिम्मत को जो इतने मुसीबतों के बाद भी हार नही माने ऐसा जाबाज न कोई हुआ है और न होगा हर हर मोदी विवेक ओबेरॉय जी को भी मेरा साधुवाद जिन्होंने मोदी जी की भूमिका इतने अच्छे से निभाया जय हिंद🇮🇳🇮🇳',
#  'OMG, movie on Modi... if I found it couple of years back I would have definitely loved it but now as my eyes are open. hope others also realize it soon. ',
#  'so proud for we  are Indian people,, and great man PM Narendra modi 🇮🇳 Jay sree ram',
#  'Eise leader bahut Kam paida hote hein..we are fortunate to have him as our PM...Jai Hind ..',
# ...

# %%
LIKEES = []
try:
    likee=driver.find_element(By.XPATH,'//*[@id="vote-count-middle"]')
    for i in like:
        LIKEES.append(i)
except NoSuchElementException:
    LIKEES.append('not found')

# %%
cmn=COMMENTs[0:500]

# %%
time=TIMEE[0:500]

# %%
LIKEES=LIKEE[0:500]

# %%
len(cmn)
len(time)
len(LIKEES)
# Out:
# 500

# %%
time
# Out:
# ['@user-tv3rl3pn3y\n21 hours ago',
#  '@user-yb2km2tq8p\n5 days ago',
#  '@pujasahu8601\n2 weeks ago',
#  '@govindchetty4641\n5 days ago',
#  '@susmita505\n2 weeks ago',
#  '@anindian2604\n4 days ago (edited)',
#  '@yashworld4980\n2 weeks ago',
#  '@dream_.ride.od01\n2 weeks ago',
#  '@zoraideale3723\n5 days ago',
#  '@SanjoyDas-on4hd\n2 days ago',
#  '@umeshraskoti8295\n2 weeks ago (edited)',
#  '@vishnupriyadutta587\n17 hours ago',
#  '@manishgoswami1910\n3 weeks ago',
#  '@sukanyaparamanik681\n3 weeks ago',
#  '@sreeradhikavishwapratishta5484\n3 weeks ago',
#  '@miku96396\n9 hours ago',
#  '@jashkothari6405\n1 month ago',
#  '@somengitdey9186\n2 weeks ago',
#  '@PrantikBhowmik402\n8 days ago',
#  '@jaigurutoursofficial\n3 weeks ago',
#  '@user-tv3rl3pn3y\n21 hours ago',
#  '@user-yb2km2tq8p\n5 days ago',
#  '@pujasahu8601\n2 weeks ago',
#  '@govindchetty4641\n5 days ago',
#  '@susmita505\n2 weeks ago',
#  '@anindian2604\n4 days ago (edited)',
#  '@yashworld4980\n2 weeks ago',
# ...

# %%
original_list = time


time_list = []

pattern = r'(\d+\s+\w+\s+ago)'

for item in original_list[0:500]:
    match = re.search(pattern, item)
    if match:
        time_list.append(match.group(1))

print(time_list)
# Out:
# ['21 hours ago', '5 days ago', '2 weeks ago', '5 days ago', '2 weeks ago', '4 days ago', '2 weeks ago', '2 weeks ago', '5 days ago', '2 days ago', '2 weeks ago', '17 hours ago', '3 weeks ago', '3 weeks ago', '3 weeks ago', '9 hours ago', '1 month ago', '2 weeks ago', '8 days ago', '3 weeks ago', '21 hours ago', '5 days ago', '2 weeks ago', '5 days ago', '2 weeks ago', '4 days ago', '2 weeks ago', '2 weeks ago', '5 days ago', '2 days ago', '2 weeks ago', '17 hours ago', '3 weeks ago', '3 weeks ago', '3 weeks ago', '9 hours ago', '1 month ago', '2 weeks ago', '8 days ago', '3 weeks ago', '21 hours ago', '5 days ago', '2 weeks ago', '5 days ago', '2 weeks ago', '4 days ago', '2 weeks ago', '2 weeks ago', '5 days ago', '2 days ago', '2 weeks ago', '17 hours ago', '3 weeks ago', '3 weeks ago', '3 weeks ago', '9 hours ago', '1 month ago', '2 weeks ago', '8 days ago', '3 weeks ago', '21 hours ago', '5 days ago', '2 weeks ago', '5 days ago', '2 weeks ago', '4 days ago', '2 weeks ago', '2 wee
# ...

# %%
df2=pd.DataFrame({'COMMENTS':cmn,'TIME':time_list,'OPVOTES':LIKEES})
df2
# Out:
#                                               COMMENTS          TIME OPVOTES
# 0    ನವ ಭಾರತದ ನಿರ್ಮಾತ್ರು ವಿಶ್ವನಾಯಕ ಭಾರತಾಂಭೆಯ ಹೆಮ್ಮೆ...  21 hours ago       4
# 1    Really I have no language to express the  grea...    5 days ago      20
# 2    नरेंद्र मोदी सिर्फ नाम नही देश की शान है नमन ह...   2 weeks ago     125
# 3    OMG, movie on Modi... if I found it couple of ...    5 days ago      39
# 4    so proud for we  are Indian people,, and great...   2 weeks ago      61
# ..                                                 ...           ...     ...
# 495                                  Our PM Our proud    2 weeks ago       2
# 496  I couldn't see our ancient freedom fighter and...   3 weeks ago      12
# 497  This movie should be dubbed into different pro...   2 weeks ago       1
# 498                       Best pm in this whole world    3 weeks ago      13
# 499                           Super man of India... 🇮🇳   3 weeks ago      11
#
# [500 rows x 3 columns]

# %% [markdown]
# # QUESTION - 9

# %%
#Q9
driver.get('https://www.hostelworld.com/')

# %%
loc=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]')
loc.click()

# %%
clickk=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/input')
clickk.send_keys('london')

# %%
london=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[2]/div/ul/li[2]/button/div[2]/div[1]')
london.click()

# %%
srch=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[5]/button[1]/div')
srch.click()

# %%
HOTELZ = []

# %%
Hlinks=driver.find_elements(By.XPATH,'//a[@class="property-card-container horizontal"]')
for i in Hlinks:
    HOTELZ.append(i.get_attribute('href'))

# %%
next_page1=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div/div[2]/div[1]/div/div/div/div/div[6]/div/div[2]/button')
next_page1.click()

# %%
Hinks=driver.find_elements(By.XPATH,'//a[@class="property-card-container horizontal"]')
for i in Hinks:
    HOTELZ.append(i.get_attribute('href'))

# %%
len(HOTELZ)
# Out:
# 48

# %%
HOTELZ
# Out:
# ["https://www.hostelworld.com/pwa/hosteldetails.php/Wombat's%20City%20Hostel%20London/London/88047?from=2023-09-10&to=2023-09-13&guests=2",
#  "https://www.hostelworld.com/pwa/hosteldetails.php/St%20Christopher's%20Village/London/502?from=2023-09-10&to=2023-09-13&guests=2",
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Onefam%20Notting%20Hill/London/291433?from=2023-09-10&to=2023-09-13&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/NX%20London%20Hostel/London/15204?from=2023-09-10&to=2023-09-13&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Urbany%20Hostel%20London/London/303427?from=2023-09-10&to=2023-09-13&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Generator%20London/London/510?from=2023-09-10&to=2023-09-13&guests=2',
#  'https://www.hostelworld.com/pwa/hosteldetails.php/Safestay%20London%20Elephant%20&%20Castle/London/55551?from=2023-09-10&to=2023-09-13&guests=2',
# ...

# %%
CENTERz= []
city_cente=driver.find_elements(By.XPATH,'//div[@class="property-distance"]')
for city in city_cente:
    CENTERz.append(city.text)

# %%
next_page2=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div/div[2]/div[1]/div/div/div/div/div[6]/div/div[2]/button')
next_page2.click()

# %%
city_centez=driver.find_elements(By.XPATH,'//div[@class="property-distance"]')
for city in city_centez:
    CENTERz.append(city.text)

# %%
len(CENTERz)
# Out:
# 48

# %%
hotelz = []
discriptionz = []
facilitiez = []
Reviewz = []
ratingz = []
treviewwz = []


for i in HOTELZ:
    driver.get(i)
    time.sleep(2)

   
    try:
        hotel_name=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/section/div[4]/div/div[1]/h1/div')
        hotelz.append(hotel_name.text)
    except NoSuchElementException:
        hotelz.append('NO_ELEMENT')
 
        
    try:
        rtn=driver.find_element(By.XPATH,'//div[@class="score orange big"]')
        ratingz.append(rtn.text)
    except NoSuchElementException:
        ratingz.append('NO_ELEMENT')  
     
    
    try:
        rvw=driver.find_element(By.XPATH,'//div[@class="keyword"]')
        Reviewz.append(rvw.text)
    except NoSuchElementException:
        Reviewz.append('NO_ELEMENT')
        
    
    try:
        trw=driver.find_element(By.XPATH,'//ul[@class="rating-breakdown rating-grid"]')
        treviewwz.append(trw.text)
    except NoSuchElementException:
        treviewwz.append('NO_ELEMENT')
    
    try:
        flt=driver.find_element(By.XPATH,'//ul[@class="facility-sections"]')
        facilitiez.append(flt.text)
    except NoSuchElementException:
        facilitiez.append('NO_ELEMENT')
        
    try:
        dsc=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/section/div[9]/div/div[2]/div[4]/div/div[2]')
        discriptionz.append(dsc.text)
    except NoSuchElementException:
        discriptionz.append('NO_ELEMENT')

# %%
FRW=treviewwz

FRW_list = [text.replace('\n', ' ') for text in FRW]


for text in FRW_list:
    print(text)
    
rewiew_list=FRW_list
# Out:
# Security 9.6 Location 8.7 Staff 9 Atmosphere 8.9 Cleanliness 9 Facilities 9 Value For Money 8.7
# Security 8.8 Location 9.1 Staff 8.5 Atmosphere 7.9 Cleanliness 7.7 Facilities 7.6 Value For Money 7.9
# Security 9.8 Location 9.8 Staff 9.9 Atmosphere 9.8 Cleanliness 9.6 Facilities 9.4 Value For Money 9.6
# Security 7.8 Location 7.9 Staff 7.8 Atmosphere 7.5 Cleanliness 7.5 Facilities 7.4 Value For Money 7.8
# Security 9.7 Location 9.6 Staff 9.8 Atmosphere 9.5 Cleanliness 9.3 Facilities 9.2 Value For Money 9.4
# Security 8.4 Location 8.7 Staff 8 Atmosphere 7.5 Cleanliness 7.1 Facilities 6.9 Value For Money 7.2
# Security 7.6 Location 7.6 Staff 6.9 Atmosphere 6.6 Cleanliness 7.2 Facilities 6.8 Value For Money 7.2
# Security 9 Location 9.1 Staff 9.1 Atmosphere 7.1 Cleanliness 7.5 Facilities 7.2 Value For Money 7.7
# Security 7.9 Location 8.5 Staff 8.4 Atmosphere 7.6 Cleanliness 6.4 Facilities 6.4 Value For Money 7.3
# ...

# %%
FAC=facilitiez

updated_list = [text.replace('\n', ' ') for text in FAC]


for text in updated_list:
    print(text)
    
FLTS=updated_list
# Out:
# Free Linen Included Free City Maps Free WiFi Free Internet Access Free City Tour General Wheelchair Friendly Security Lockers Key Card Access Common Room Elevator Bicycle Parking BBQ Breakfast Not Included Meeting Rooms Adaptors Book Exchange Hot Showers Self-Catering Facilities Dishwasher Cooker Fridge/Freezer Utensils Dryer Outdoor Terrace Reading Light Hair Dryers For Hire Iron / Ironing Board Safe Deposit Box Microwave Washing Machine Follows Covid-19 sanitation guidance Services Internet access Laundry Facilities Towels for hire Luggage Storage Fax Service 24 Hour Reception ATM Housekeeping Internet café Late check-out Food & Drink Bar Meals Available Vending Machines Cafe Tea & Coffee Making Facilities Entertainment Board Games Pool Table Foosball Wi-Fi
# ...

# %%
discriptionz
print(len(discriptionz))
# Out:
# 48

# %%
FAC=facility

updated_list = [text.replace('\n', ' ') for text in FAC]


for text in updated_list:
    print(text)
fac_list=updated_list
# Out:
# Free Linen Included Free City Maps Free WiFi Free Internet Access Free City Tour General Wheelchair Friendly Security Lockers Key Card Access Common Room Elevator Bicycle Parking BBQ Breakfast Not Included Meeting Rooms Adaptors Book Exchange Hot Showers Self-Catering Facilities Dishwasher Cooker Fridge/Freezer Utensils Dryer Outdoor Terrace Reading Light Hair Dryers For Hire Iron / Ironing Board Safe Deposit Box Microwave Washing Machine Follows Covid-19 sanitation guidance Services Internet access Laundry Facilities Towels for hire Luggage Storage Fax Service 24 Hour Reception ATM Housekeeping Internet café Late check-out Food & Drink Bar Meals Available Vending Machines Cafe Tea & Coffee Making Facilities Entertainment Board Games Pool Table Foosball Wi-Fi
# ...

# %%
private = []
amts=driver.find_elements(By.XPATH,'//div[@class="property-accommodation-prices"]')
for amt in amts:
    private.append(amt.text)

# %%
next_page1=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div/div[2]/div[1]/div/div/div/div/div[6]/div/div[2]/button')
next_page1.click()

# %%
amtzs=driver.find_elements(By.XPATH,'//div[@class="property-accommodation-prices"]')
for amt in amtzs:
    private.append(amt.text)

# %%
len(private)
# Out:
# 48

# %%
private
# Out:
# ['No Privates Available\n-20%\nDorms From\n₹3,787\n₹3,030',
#  'No Privates Available\n-10%\nDorms From\n₹2,136\n₹1,923',
#  'Privates From\n₹11,306\nNo Dorms Available',
#  'No Privates Available\nDorms From\n₹2,245',
#  'No Privates Available\nDorms From\n₹2,741',
#  'Privates From\n₹10,589\nDorms From\n₹2,220',
#  'Privates From\n₹11,189\nDorms From\n₹1,722',
#  'Privates From\n₹9,926\nDorms From\n₹2,417',
#  'No Privates Available\n-5%\nDorms From\n₹1,674\n₹1,590',
#  'No Privates Available\nDorms From\n₹1,597',
#  'No Privates Available\nDorms From\n₹1,118',
#  'No Privates Available\nDorms From\n₹4,923',
#  'No Privates Available\nDorms From\n₹1,615',
#  'No Privates Available\nDorms From\n₹1,118',
#  'No Privates Available\nDorms From\n₹1,679',
#  'No Privates Available\nDorms From\n₹3,820',
#  'No Privates Available\n-15%\nDorms From\n₹3,593\n₹3,054',
#  'No Privates Available\n-10%\nDorms From\n₹1,426\n₹1,283',
#  'No Privates Available\n-10%\nDorms From\n₹2,136\n₹1,922',
# ...

# %%
ccc=private

rooms = [text.replace('\n', '') for text in ccc]

for text in rooms:
    print(text)
price_list=rooms
# Out:
# No Privates Available-20%Dorms From₹3,787₹3,030
# No Privates Available-10%Dorms From₹2,136₹1,923
# Privates From₹11,306No Dorms Available
# No Privates AvailableDorms From₹2,245
# No Privates AvailableDorms From₹2,741
# Privates From₹10,589Dorms From₹2,220
# Privates From₹11,189Dorms From₹1,722
# Privates From₹9,926Dorms From₹2,417
# No Privates Available-5%Dorms From₹1,674₹1,590
# No Privates AvailableDorms From₹1,597
# No Privates AvailableDorms From₹1,118
# No Privates AvailableDorms From₹4,923
# No Privates AvailableDorms From₹1,615
# No Privates AvailableDorms From₹1,118
# No Privates AvailableDorms From₹1,679
# No Privates AvailableDorms From₹3,820
# No Privates Available-15%Dorms From₹3,593₹3,054
# No Privates Available-10%Dorms From₹1,426₹1,283
# No Privates Available-10%Dorms From₹2,136₹1,922
# No Privates AvailableDorms From₹2,893
# No Privates AvailableDorms From₹1,804
# Privates From₹9,071Dorms From₹2,591
# No Privates Available-10%Dorms From₹1,561₹1,405
# ...

# %%
rl=price_list

rms = [text.replace('₹', ' ') for text in rl]

for text in rms:
    print(text)
bbb=rms
# Out:
# No Privates Available-20%Dorms From 3,787 3,030
# No Privates Available-10%Dorms From 2,136 1,923
# Privates From 11,306No Dorms Available
# No Privates AvailableDorms From 2,245
# No Privates AvailableDorms From 2,741
# Privates From 10,589Dorms From 2,220
# Privates From 11,189Dorms From 1,722
# Privates From 9,926Dorms From 2,417
# No Privates Available-5%Dorms From 1,674 1,590
# No Privates AvailableDorms From 1,597
# No Privates AvailableDorms From 1,118
# No Privates AvailableDorms From 4,923
# No Privates AvailableDorms From 1,615
# No Privates AvailableDorms From 1,118
# No Privates AvailableDorms From 1,679
# No Privates AvailableDorms From 3,820
# No Privates Available-15%Dorms From 3,593 3,054
# No Privates Available-10%Dorms From 1,426 1,283
# No Privates Available-10%Dorms From 2,136 1,922
# No Privates AvailableDorms From 2,893
# No Privates AvailableDorms From 1,804
# Privates From 9,071Dorms From 2,591
# No Privates Available-10%Dorms From 1,561 1,405
# ...

# %%
lines = bbb

privates_list = []
dorms_list = []

for line in lines:
    privates_match = re.search(r'Privates From (\d+(?:,\d+)*)', line)
    dorms_match = re.search(r'Dorms From (\d+(?:,\d+)*)', line)
    
    privates_rate = privates_match.group(1) if privates_match else "No Privates Available"
    dorms_rate = dorms_match.group(1) if dorms_match else "No Dorms Available"
    
    privates_list.append(privates_rate)
    dorms_list.append(dorms_rate)


print("Privates List:")
print(privates_list)
print("\nDorms List:")
print(dorms_list)
# Out:
# Privates List:
# ['No Privates Available', 'No Privates Available', '11,306', 'No Privates Available', 'No Privates Available', '10,589', '11,189', '9,926', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', 'No Privates Available', '9,071', 'No Privates Available', 'No Privates Available', 'No Privates Available', '26,120', '9,190', 'No Privates Available', 'No Privates Available', '21,435', '43,119', 'No Privates Available', '9,173', '8,210', '29,541', '24,565', 'No Privates Available', '29,541', '11,056', '49,443', 'No Privates Available', '7,843', '27,571', '7,774', '30,232', '7,774', 'No Privates Available', '7,774']
#
# Dorms List:
# ...

# %%
df5=pd.DataFrame({'HOTEL':hotelz,'RATING':ratingz,'REVIEW':Reviewz,'OVER_ALL_REVIEWS':rewiew_list,'DISTANCE_FROM_CITY_CENTER':CENTERz,'PRICE_PRIVATE':privates_list,'PRICE_DORMS':dorms_list,'FACILITY':FLTS,'DISCRIPTION':discriptionz})

# %%
df5
# Out:
#                                       HOTEL      RATING     REVIEW  \
# 0               Wombat's City Hostel London         9.0     Superb
# 1                  St Christopher's Village         8.2   Fabulous
# 2                       Onefam Notting Hill         9.7     Superb
# 3                          NX London Hostel         7.7  Very Good
# 4                      Urbany Hostel London         9.5     Superb
# 5                          Generator London         7.7  Very Good
# 6         Safestay London Elephant & Castle         7.1  Very Good
# 7                                  Clink261         8.1   Fabulous
# 8                            Phoenix Hostel         7.5  Very Good
# 9   Safestay London Kensington Holland Park         7.0  Very Good
# 10             No.8 Willesden Hostel London         6.7       Good
# 11       Destinations Hostels @ The Gallery         9.2     Superb
# 12                  Queen Elizabeth Chelsea         7.5  Very Good
# ...
